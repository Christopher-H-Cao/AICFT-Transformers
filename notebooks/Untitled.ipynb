# %%
import wandb
import pandas as pd
import matplotlib.pyplot as plt
import os
import sys  
sys.path.insert(1, '/home/garrett/work/ChromoBoot_CFT/')
print(os.getcwd())
from rels_utils import get_dihedral_images, get_rel_instances_in_symb, replace_trivial0_terms
from src.envs.encoders import Rational
import json
api = wandb.Api()
plt.rcParams["font.family"] = "Liberation Serif"
plt.rcParams.update({'font.size': 15})
from collections import Counter, OrderedDict
import itertools
from itertools import islice
# Out:
# /home/garrett/work/ChromoBoot_CFT/notebooks

# %%
f2 = open("../../ChromoBoot_data/processed_data/strikethrough/loop4_dummyfrac_all_unique.prefix.train")

# %%
myrat = Rational(1000)
myrat.decode(myrat.encode(12/54))
# Out:
# ['2'] ['9']
# Fraction(2, 9)

# %%
len(traindict.keys() & mydata.keys())
len(mydata.keys())
# Out:
# 40826

# %%
print(rels_nonzero)
# Out:
# {'bbacacdcafbd': 496, 'bbacacdcafae': -416, 'bbacacdcafaf': -416, 'bbacacdcafbf': 496, 'bacacdcaffaf': -64, 'bacacdcaffbf': -288, 'bacacdcafaff': -64, 'bacacdcafbff': -288, 'acacdcaffaae': 1152, 'acacdcaffaaf': 1152, 'cacdcaffafae': -320, 'cacdcaffbfae': -512, 'cacdcafaffae': -320, 'cacdcafbffae': -512, 'bdceccdceccd': 3584, 'bdceccdcecce': 3584, 'ccdcecabdbbf': -384, 'ccdcecabbdbf': -192, 'ccdcecabcdbf': 192, 'ccdcecabfbbf': -192, 'ccdcecabafbf': 96, 'ccdcecabbfbf': -96, 'cabbfbbabdce': 128, 'cabbfbbabcee': -128, 'cabbfbbabaee': 128, 'cabbfbbabfae': -128, 'aacbfbaabdbd': -48, 'aacbfbaabdcd': 240, 'aacbfbaabdce': 240, 'aacbfbaabdbf': -48, 'cbcafbcaabdd': -208, 'cbcafbcaacdd': 208, 'cbcafbcaaecd': -208, 'cbcafbcaafbd': 208, 'cbdbabffbfbd': -256, 'cbdbabffbfae': -160, 'cbdbabffbfaf': -160, 'cbdbabffbfbf': -256, 'cbbccbdbfaae': 1664, 'cbbccbfafaae': -1120, 'cbbccbfbfaae': 1664, 'cbbccbaffaae': -512, 'cbbccbbffaae': 512, 'cbbccbcbfaae': 48, 'bccbfaaecece': -224, 'bccbfaaeaece': -512, 'bc
# ...

# %%
#nonzero
overlap_nonzero=len(traindict_nonzero.keys() & rels_nonzero.keys())
num_rels_nonzero=len(rels_nonzero.keys())
num_train_nonzero=len(traindict_nonzero.keys())

#with zero
overlap=len(traindict.keys() & rels.keys())
num_rels=len(rels.keys())
num_train=len(traindict.keys())

# %%
print(overlap_nonzero/num_rels_nonzero)
# Out:
# 0.9907475761602441

# %%
print(overlap_nonzero/counter_nonzero)
# Out:
# 0.0041364139216598424
